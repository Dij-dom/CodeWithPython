# %% [markdown]
# Statistics & Analytics Logic (MCQs / Small Coding)
#
# Mean vs median — when is median preferred?
#
# What happens to mean if there are outliers?
#
# Variance vs standard deviation.
#
# Correlation vs causation.
#
# When is accuracy a bad metric?
#
# 5️⃣ ML Concepts (LIGHT, CONCEPTUAL)
#
# Overfitting vs underfitting.
#
# Bias–variance tradeoff.
#
# Difference between supervised & unsupervised learning.
#
# Precision vs recall — business interpretation.
#
# Linear regression assumptions.
#
# ❌ No need to implement models.
#
# 6️⃣ Realistic Coding Scenarios (IBM STYLE)
#
# These are VERY likely.
#
# Given sales data, find total sales per region.
#
# Given user events, find active users.
#
# Given timestamps, calculate duration.
#
# Identify anomalies using simple rules.
#
# Convert raw data into aggregated metrics.
#
# 👉 Think like a business analyst with code.
#
# 7️⃣ Output Prediction (MCQ FAVORITE)
#
# Predict output of list slicing.
#
# Predict output of dictionary mutation.
#
# Predict output of zip, map, filter.
#
# Predict output of pandas operations.
#
# Predict output of boolean indexing.
#
# 8️⃣ Pythonic Thinking (BONUS EDGE)
#
# List comprehension vs for loop.
#
# Generator vs list.
#
# When to use enumerate.
#
# Use of Counter.
#
# Exception handling best practices.

# %%
a = [1,2,3,4,5]
a[1:4]   # [2,3,4]
a[::-1]  # reversed
# Out:
# [5, 4, 3, 2, 1]

# %%
# Dictionaru Mutation
d = {"a":1}
x = d
x["b"] = 2
# d is modified
d
# Out:
# {'a': 1, 'b': 2}

# %%
# zip
list(zip([1,2],[3,4,5]))  # [(1,3),(2,4)]
# Out:
# [(1, 3), (2, 4)]

# %%
# map/filter
list(map(lambda x: x*2, [1,2,3]))
# Out:
# [2, 4, 6]

# %%
list(filter(lambda x: x>2, [1,2,3]))
# Out:
# [3]

# %%
# pandas boolean indexing
# df[df["salary"] > 50000]
